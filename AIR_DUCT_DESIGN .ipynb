# %% [markdown]
# ## 风道设计

# %% [markdown]
#         风道系统是无霜冰箱制冷系统的关键子系统，蒸发器产生的制冷量，需要被流经蒸发器的气流带走，输送到箱体的各个子间室实现制冷功能，输入到各间室的气流通过回风道再经过蒸发器实现循环。
#         冰箱风道系统构成：（1）风机、（2）蒸发器室风道 （3）送风风道 （4）回风风道、（5）风门控制器。根据不同冰箱类型，风道设计会有不同的结构和参数，但其设计要求都是相同的，可归纳为如下几点：
#         1）保证系统获得尽可能大的通风量并减少流动压力损失
#         2）保证制冷量的分配满足冰箱系统制冷功能要求
#         3）优化蒸发器工况，保证系统制冷量和COP达到设计指标
#         4）优化气流噪音

# %% [markdown]
# ## 风机的选型
#         冰箱系统中需要使用风机的场合有三种：
#     （1）为翅片蒸发器制冷提供循环空气流
#     （2）为冷凝器提供冷风散热
#     （3）在直冷冰箱间室中增强空气对流，提高间室温度场的均匀性
#     其中（1）蒸发风机和（2）冷凝风机都对系统性能有非常重要的作用，（3）只是起锦上添花的作用，对系统工况影响不大，忽略。
#     用作箱内制冷循环风机时，需要克服蒸发器、风道和间室的空气流动阻力，而且是在截面积很小的空间内流动，所以不仅要求风机要提供足够的风量，还要有足够大的静压才能保证风机能够满足系统要求。
#     轴流风机的特点是风量大，但提供的静压较小，所以不适合在系统阻力较大的场合内应用，如500L以上的大冰箱中，目前国内主流产品都转向使用离心风机作为制冷风机；但用在冷凝器上就非常合适了，因为冷凝器散热只需要从一侧吸入从另一侧吹出，不允许出现回流，所以系统阻力很小，而且由于提供风量较大，在较低转速条件下就能满足系统散热要求，噪音也能得到有效控制。
# <img src="fan_curve.png" width="50%">
# <img src="轴流式制冷风扇">
# <img src="轴流式冷凝风扇">

# %%
####风机的类型
轴流风机
离心风机
贯流风机

# %%
#### 制冷风机的选型
###### 制冷风机对蒸发器换热性能的影响：
制冷风机需要提供足够的风量给蒸发器，以保证蒸发器有足够高的换热能力，在设计工况条件下正常工作。
###### 离心和轴流风机用作制冷风机的区别

# %%
    
    
    
    （3）为常用的风机类型有轴流风机和离心风机两种，从目前国内外产品设计趋势来看，在箱内风道设计中，离心式风机由于其占用体积小、风量大、噪音低的特点，在冰箱系统设计中的应用越来越普遍；而轴流风机主要应用在小容积冰箱系统和外置冷凝风机系统中。
<img src="1.png" width="20%">

# %% [markdown]
# ### 风机选型
# F-1:离心风机都选择后向叶轮结构的扇叶，出风方式
#
# F-2:风机的风量与系统阻力
#
# F-3：冰箱系统选择蒸发风机的原则

# %% [markdown]
# ### 离心风机的风道设计
#         蒸发器风机全部采取吸风设计，蒸发器位于气流上游，送风均匀，换热效果好；蒸发器充当了除湿器的作用，风机上不容易结冰；同时在重力方向上处于高位，不存在化霜水排出的问题;
#         离心风机的特点是气流进入后，偏转90度再被甩出，气流方向由垂直于风道内壁转换成平行于风道内壁，大幅减少了风道系统阻力。
# #### 离心风机的出风流线和为什么要制作蜗壳
# #### 离心风道的蜗壳设计
# #### 实际冰箱离心风道的设计

# %% [markdown]
# #### 离心风机的出风设计
#         由于离心风机的出风是从扇叶中心向扇叶四周流动，所以就需要有相应的导流结构将气流收集并导出，同时降低出口流速，将部分动压转换成静压，以降低能量损失，提高风机系统效率,如图所示，越靠近出口速越低，静压越高。
#
# <img src="blower-arrows.png" width="50%">
# <img src="static-pressure.png" width="50%">

# %% [markdown]
# #### 离心风机的蜗壳结构画法
